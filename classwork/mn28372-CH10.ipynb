# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

x = np.arange(0,1.01,0.01)

m = 3
b = 2

error = np.random.uniform(-1,1,len(x))

y = m*x+b+error


A = np.vstack([x, np.ones(len(x))]).T
m_fit, b_fit = np.linalg.lstsq(A,y,rcond=None)[0]

y_line = m_fit*x+b_fit


degree = 3
coeff = np.polyfit(x,y,degree)

poly = np.poly1d(coeff)

y_poly = poly(x)


def mse(y_true,y_pred):
    return np.mean((y_true-y_pred)**2)

def r2(y_true,y_pred):
    ss_res = np.sum((y_true-y_pred)**2)
    ss_tot = np.sum((y_true-np.mean(y_true))**2)
    return 1-ss_res/ss_tot


mse_line = mse(y,y_line)
r2_line = r2(y,y_line)

mse_poly = mse(y,y_poly)
r2_poly = r2(y,y_poly)

print("Linear Fit MSE:",mse_line)
print("Linear Fit R2:",r2_line)

print("Polynomial Fit MSE:",mse_poly)
print("Polynomial Fit R2:",r2_poly)

if mse_line < mse_poly:
    print("Linear fit better")
else:
    print("Polynomial fit better")


plt.scatter(x,y,label="Data Points")
plt.plot(x,y_line,label="Least Squares Line")
plt.plot(x,y_poly,label="Cubic Polynomial")

plt.title("Linear vs Polynomial Fit")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()



print("\nTest diff polynomial degrees")

for d in range(1,10):

    coeff = np.polyfit(x,y,d)

    poly = np.poly1d(coeff)

    y_pred = poly(x)

    m = mse(y,y_pred)
    r = r2(y,y_pred)

    print("Degree:",d," MSE:",m," R2:",r)



degree = 3

V = np.vander(x,degree+1,increasing=True)

coeff_v = np.linalg.lstsq(V,y,rcond=None)[0]

y_v = V @ coeff_v

mse_v = mse(y,y_v)
r2_v = r2(y,y_v)

print("\nVandermonde Results")
print("MSE:",mse_v)
print("R2:",r2_v)

plt.scatter(x,y,label="Data Points")
plt.plot(x,y_v,label="Vandermonde Fit")

plt.title("Vandermonde Polynomial Fit")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Linear Fit MSE: 0.31232606762708964
# Linear Fit R2: 0.6359363309347539
# Polynomial Fit MSE: 0.30824735683136273
# Polynomial Fit R2: 0.6406906904687821
# Polynomial fit better
# Test diff polynomial degrees
# Degree: 1  MSE: 0.3123260676270897  R2: 0.6359363309347539
# Degree: 2  MSE: 0.3089400636393884  R2: 0.6398832350295601
# Degree: 3  MSE: 0.30824735683136273  R2: 0.6406906904687821
# Degree: 4  MSE: 0.3072787704538241  R2: 0.6418197256245487
# Degree: 5  MSE: 0.30715330562736565  R2: 0.6419659740161932
# Degree: 6  MSE: 0.30660791248017744  R2: 0.6426017129148286
# Degree: 7  MSE: 0.3063072271240402  R2: 0.6429522075591637
# Degree: 8  MSE: 0.30538736721264054  R2: 0.6440244445866858
# Degree: 9  MSE: 0.30538565588705147  R2: 0.6440264393976783
#
# Vandermonde Results
# MSE: 0.30824735683136284
# R2: 0.6406906904687819
