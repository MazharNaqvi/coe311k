# %%
i = 21474836647
print(i)
# Out:
# 21474836647

# %%
i=(i+1)
print(i)
# Python 3 gives you more memory/bytes to hold whatever number you throw at it
#Thats why it is able to run a number larger than the so called max
# Out:
# 21474836648
